# %% [markdown]
# https://www.kaggle.com/competitions/amex-default-prediction/data

# %%
import gc
import os
import psutil
import pyarrow as pa
import pandas as pd

# %%
current_directory = os.getcwd()
print("Current working directory:", current_directory)
# Out:
# Current working directory: C:\Users\KonuTech\zoomcamp-capstone-01\notebooks

# %%
# !ls -lah "C:\Users\KonuTech\zoomcamp-capstone-01\data"
# Out:
# total 36G
# drwxr-xr-x 1 KonuTech 197121   0 Oct 30 19:01 .
# drwxr-xr-x 1 KonuTech 197121   0 Oct 29 19:44 ..
# drwxr-xr-x 1 KonuTech 197121   0 Oct 30 19:01 parquet_partitions
# -rw-r--r-- 1 KonuTech 197121 60M May 20  2022 sample_submission.csv
# -rw-r--r-- 1 KonuTech 197121 32G May 20  2022 test_data.csv
# -rw-r--r-- 1 KonuTech 197121 16G May 20  2022 train_data.csv
# -rw-r--r-- 1 KonuTech 197121 30M May 20  2022 train_labels.csv

# %%
# Function to get memory usage
def get_memory_usage():
    process = psutil.Process()
    mem_info = process.memory_info()
    return mem_info.rss / (1024 * 1024)  # Convert to megabytes

# %%
# Define the directory path
data_dir = os.path.join('C:\\', 'Users', 'KonuTech', 'zoomcamp-capstone-01', 'data')
data_dir
# Out:
# 'C:\\Users\\KonuTech\\zoomcamp-capstone-01\\data'

# %%
parquet_dir = os.path.join(data_dir, 'parquet_partitions')
parquet_dir
# Out:
# 'C:\\Users\\KonuTech\\zoomcamp-capstone-01\\data\\parquet_partitions'

# %%
# List of file names to remove
files_to_remove = ['train_data.parquet', 'train_labels.parquet']
# Remove the files if they exist
for file_name in files_to_remove:
    file_path = os.path.join(data_dir, file_name)
    if os.path.exists(file_path):
        os.remove(file_path)

# %%
if os.path.exists(parquet_dir) and os.path.isdir(parquet_dir):
    # Directory exists, list all files in the directory
    file_list = os.listdir(parquet_dir)
    
    if file_list:
        print("List of files in the directory:")
        for filename in file_list:
            print(filename)
        
        # Delete all files in the directory
        for filename in file_list:
            file_path = os.path.join(parquet_dir, filename)
            os.remove(file_path)
            print(f"Deleted: {filename}")
    else:
        print("The directory is empty, no files to delete.")
else:
    print(f"The directory '{parquet_dir}' does not exist.")
# Out:
# The directory is empty, no files to delete.

# %% [markdown]
# ### train_labels.csv

# %%
# Load the CSV file (train_labels.csv)
csv_file = 'train_labels.csv'
train_labels_csv_file = os.path.join(data_dir, csv_file)
train_labels = pd.read_csv(train_labels_csv_file)

# %%
# Convert the DataFrame to Parquet format
parquet_file = 'train_labels.parquet'
train_labels.to_parquet(f"{data_dir}\\{parquet_file}", index=False)

# %%
train_labels_parquet_file = os.path.join(data_dir, parquet_file)
train_labels = pd.read_parquet(train_labels_parquet_file)

# %%
train_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458913 entries, 0 to 458912
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_ID  458913 non-null  object
#  1   target       458913 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 7.0+ MB

# %%
train_labels.describe()
# Out:
#               target
# count  458913.000000
# mean        0.258934
# std         0.438050
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# ### train_data.csv

# %%
# Step 1: Read the CSV file in chunks
csv_file = 'train_data.csv'

# %%
# Step 2: Initialize an empty list to store the Parquet partition file paths
parquet_file_paths = []

# %%
chunk_size = 100000  # Adjust the chunk size as needed
i = 0  # Initialize the chunk number
cumulative_rows = 0  # Initialize the cumulative row count

if not os.path.exists(parquet_dir):
    os.makedirs(parquet_dir)

# %%
# Create a TextFileReader, which is iterable with chunks of 10,000 rows.
csv_iterator = pd.read_csv(os.path.join(data_dir, csv_file), iterator=True, chunksize=chunk_size)

parquet_file_paths = []  # Initialize the list to store Parquet partition file paths

# %%
# Iterate through the CSV file in chunks using pd.read_csv
for chunk in csv_iterator:
    # Display memory usage before reading the chunk
    before_memory = get_memory_usage()

    # Count and print the number of rows in the chunk
    num_rows = len(chunk)
    cumulative_rows += num_rows  # Accumulate the row count
    print(f"Processing chunk {i}, rows: {num_rows}, cumulative rows: {cumulative_rows}")

    # Save the chunk as a Parquet partition
    parquet_partition_file = os.path.join(parquet_dir, f'chunk_{i}.parquet')
    chunk.to_parquet(parquet_partition_file, index=False)

    # Append the Parquet partition file path to the list
    parquet_file_paths.append(parquet_partition_file)

    # Display memory usage after reading and saving the chunk
    after_memory = get_memory_usage()
    print(f"Memory usage before chunk: {before_memory:.2f} MB")
    print(f"Memory usage after chunk: {after_memory:.2f} MB")

    i += 1  # Increment the chunk number
# Out:
# Processing chunk 0, rows: 100000, cumulative rows: 100000
# Memory usage before chunk: 432.18 MB
# Memory usage after chunk: 454.99 MB
# Processing chunk 1, rows: 100000, cumulative rows: 200000
# Memory usage before chunk: 456.03 MB
# Memory usage after chunk: 474.27 MB
# Processing chunk 2, rows: 100000, cumulative rows: 300000
# Memory usage before chunk: 473.42 MB
# Memory usage after chunk: 491.98 MB
# Processing chunk 3, rows: 100000, cumulative rows: 400000
# Memory usage before chunk: 491.10 MB
# Memory usage after chunk: 509.40 MB
# Processing chunk 4, rows: 100000, cumulative rows: 500000
# Memory usage before chunk: 508.31 MB
# Memory usage after chunk: 510.12 MB
# Processing chunk 5, rows: 100000, cumulative rows: 600000
# Memory usage before chunk: 509.25 MB
# Memory usage after chunk: 526.09 MB
# Processing chunk 6, rows: 100000, cumulative rows: 700000
# Memory usage before chunk: 525.17 MB
# Memory usage after chunk: 543.18 MB
# Processing chunk 7, rows: 100000, cumulative rows: 800000
# Memory usage before chunk: 542.42 MB
# Memory usage after chunk: 558.90 MB
# Processing chunk 8, rows: 100000, cumulative rows: 900000
# Memory usage before chunk: 558.18 MB
# Memory usage after chunk: 575.43 MB
# Processing chunk 9, rows: 100000, cumulative rows: 1000000
# Memory usage before chunk: 575.40 MB
# Memory usage after chunk: 560.53 MB
# Processing chunk 10, rows: 100000, cumulative rows: 1100000
# Memory usage before chunk: 559.16 MB
# Memory usage after chunk: 576.52 MB
# Processing chunk 11, rows: 100000, cumulative rows: 1200000
# Memory usage before chunk: 575.62 MB
# Memory usage after chunk: 590.11 MB
# Processing chunk 12, rows: 100000, cumulative rows: 1300000
# Memory usage before chunk: 591.21 MB
# Memory usage after chunk: 591.68 MB
# Processing chunk 13, rows: 100000, cumulative rows: 1400000
# Memory usage before chunk: 590.82 MB
# Memory usage after chunk: 591.48 MB
# Processing chunk 14, rows: 100000, cumulative rows: 1500000
# Memory usage before chunk: 590.16 MB
# Memory usage after chunk: 591.96 MB
# Processing chunk 15, rows: 100000, cumulative rows: 1600000
# Memory usage before chunk: 591.18 MB
# Memory usage after chunk: 593.31 MB
# Processing chunk 16, rows: 100000, cumulative rows: 1700000
# Memory usage before chunk: 593.01 MB
# Memory usage after chunk: 608.80 MB
# Processing chunk 17, rows: 100000, cumulative rows: 1800000
# Memory usage before chunk: 607.75 MB
# Memory usage after chunk: 608.95 MB
# Processing chunk 18, rows: 100000, cumulative rows: 1900000
# Memory usage before chunk: 607.91 MB
# Memory usage after chunk: 624.21 MB
# Processing chunk 19, rows: 100000, cumulative rows: 2000000
# Memory usage before chunk: 622.54 MB
# Memory usage after chunk: 639.05 MB
# Processing chunk 20, rows: 100000, cumulative rows: 2100000
# Memory usage before chunk: 639.00 MB
# Memory usage after chunk: 608.30 MB
# Processing chunk 21, rows: 100000, cumulative rows: 2200000
# Memory usage before chunk: 606.82 MB
# Memory usage after chunk: 623.92 MB
# Processing chunk 22, rows: 100000, cumulative rows: 2300000
# Memory usage before chunk: 624.23 MB
# Memory usage after chunk: 609.59 MB
# Processing chunk 23, rows: 100000, cumulative rows: 2400000
# Memory usage before chunk: 607.85 MB
# Memory usage after chunk: 609.76 MB
# Processing chunk 24, rows: 100000, cumulative rows: 2500000
# Memory usage before chunk: 609.32 MB
# Memory usage after chunk: 626.24 MB
# Processing chunk 25, rows: 100000, cumulative rows: 2600000
# Memory usage before chunk: 625.06 MB
# Memory usage after chunk: 641.78 MB
# Processing chunk 26, rows: 100000, cumulative rows: 2700000
# Memory usage before chunk: 640.02 MB
# Memory usage after chunk: 625.17 MB
# Processing chunk 27, rows: 100000, cumulative rows: 2800000
# Memory usage before chunk: 625.74 MB
# Memory usage after chunk: 627.07 MB
# Processing chunk 28, rows: 100000, cumulative rows: 2900000
# Memory usage before chunk: 625.74 MB
# Memory usage after chunk: 640.61 MB
# Processing chunk 29, rows: 100000, cumulative rows: 3000000
# Memory usage before chunk: 639.81 MB
# Memory usage after chunk: 625.19 MB
# Processing chunk 30, rows: 100000, cumulative rows: 3100000
# Memory usage before chunk: 624.62 MB
# Memory usage after chunk: 609.91 MB
# Processing chunk 31, rows: 100000, cumulative rows: 3200000
# Memory usage before chunk: 608.93 MB
# Memory usage after chunk: 625.79 MB
# Processing chunk 32, rows: 100000, cumulative rows: 3300000
# Memory usage before chunk: 625.47 MB
# Memory usage after chunk: 625.63 MB
# Processing chunk 33, rows: 100000, cumulative rows: 3400000
# Memory usage before chunk: 623.77 MB
# Memory usage after chunk: 625.35 MB
# Processing chunk 34, rows: 100000, cumulative rows: 3500000
# Memory usage before chunk: 624.35 MB
# Memory usage after chunk: 640.91 MB
# Processing chunk 35, rows: 100000, cumulative rows: 3600000
# Memory usage before chunk: 640.65 MB
# Memory usage after chunk: 610.43 MB
# Processing chunk 36, rows: 100000, cumulative rows: 3700000
# Memory usage before chunk: 609.76 MB
# Memory usage after chunk: 611.37 MB
# Processing chunk 37, rows: 100000, cumulative rows: 3800000
# Memory usage before chunk: 610.80 MB
# Memory usage after chunk: 625.19 MB
# Processing chunk 38, rows: 100000, cumulative rows: 3900000
# Memory usage before chunk: 625.07 MB
# Memory usage after chunk: 610.82 MB
# Processing chunk 39, rows: 100000, cumulative rows: 4000000
# Memory usage before chunk: 609.82 MB
# Memory usage after chunk: 626.68 MB
# Processing chunk 40, rows: 100000, cumulative rows: 4100000
# Memory usage before chunk: 626.60 MB
# Memory usage after chunk: 625.45 MB
# Processing chunk 41, rows: 100000, cumulative rows: 4200000
# Memory usage before chunk: 623.90 MB
# Memory usage after chunk: 609.77 MB
# Processing chunk 42, rows: 100000, cumulative rows: 4300000
# Memory usage before chunk: 608.48 MB
# Memory usage after chunk: 625.30 MB
# Processing chunk 43, rows: 100000, cumulative rows: 4400000
# Memory usage before chunk: 624.92 MB
# Memory usage after chunk: 626.41 MB
# Processing chunk 44, rows: 100000, cumulative rows: 4500000
# Memory usage before chunk: 624.84 MB
# Memory usage after chunk: 625.97 MB
# Processing chunk 45, rows: 100000, cumulative rows: 4600000
# Memory usage before chunk: 623.82 MB
# Memory usage after chunk: 625.29 MB
# Processing chunk 46, rows: 100000, cumulative rows: 4700000
# Memory usage before chunk: 624.11 MB
# Memory usage after chunk: 625.61 MB
# Processing chunk 47, rows: 100000, cumulative rows: 4800000
# Memory usage before chunk: 625.15 MB
# Memory usage after chunk: 641.88 MB
# Processing chunk 48, rows: 100000, cumulative rows: 4900000
# Memory usage before chunk: 641.87 MB
# Memory usage after chunk: 641.32 MB
# Processing chunk 49, rows: 100000, cumulative rows: 5000000
# Memory usage before chunk: 640.17 MB
# Memory usage after chunk: 610.55 MB
# Processing chunk 50, rows: 100000, cumulative rows: 5100000
# Memory usage before chunk: 609.77 MB
# Memory usage after chunk: 579.52 MB
# Processing chunk 51, rows: 100000, cumulative rows: 5200000
# Memory usage before chunk: 578.84 MB
# Memory usage after chunk: 578.21 MB
# Processing chunk 52, rows: 100000, cumulative rows: 5300000
# Memory usage before chunk: 577.34 MB
# Memory usage after chunk: 578.67 MB
# Processing chunk 53, rows: 100000, cumulative rows: 5400000
# Memory usage before chunk: 579.22 MB
# Memory usage after chunk: 580.97 MB
# Processing chunk 54, rows: 100000, cumulative rows: 5500000
# Memory usage before chunk: 579.66 MB
# Memory usage after chunk: 594.79 MB
# Processing chunk 55, rows: 31451, cumulative rows: 5531451
# Memory usage before chunk: 494.16 MB
# Memory usage after chunk: 499.81 MB

# %%
# Concatenate the Parquet partitions into a single DataFrame
parquet_partitions = [pd.read_parquet(partition) for partition in parquet_file_paths]
df = pd.concat(parquet_partitions, ignore_index=True)

# %%
# Trigger garbage collection to clear unreferenced objects
gc.collect()
# Out:
# 18

# %% [markdown]
# ### Merge

# %%
# Merge the DataFrames on the "customer_ID" column
merged_df = pd.merge(df, train_labels, on="customer_ID", how="left")

# %%
merged_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Data columns (total 191 columns):
#  #    Column       Dtype
# ---   ------       -----
#  0    customer_ID  object
#  1    S_2          object
#  2    P_2          float64
#  3    D_39         float64
#  4    B_1          float64
#  5    B_2          float64
#  6    R_1          float64
#  7    S_3          float64
#  8    D_41         float64
#  9    B_3          float64
#  10   D_42         float64
#  11   D_43         float64
#  12   D_44         float64
#  13   B_4          float64
#  14   D_45         float64
#  15   B_5          float64
#  16   R_2          float64
#  17   D_46         float64
#  18   D_47         float64
#  19   D_48         float64
#  20   D_49         float64
#  21   B_6          float64
#  22   B_7          float64
#  23   B_8          float64
#  24   D_50         float64
#  25   D_51         float64
#  26   B_9          float64
#  27   R_3          float64
#  175  D_132        float64
#  176  D_133        float64
#  177  R_28         float64
#  178  D_134        float64
#  179  D_135        float64
#  180  D_136        float64
#  181  D_137        float64
#  182  D_138        float64
#  183  D_139        float64
#  184  D_140        float64
#  185  D_141        float64
#  186  D_142        float64
#  187  D_143        float64
#  188  D_144        float64
#  189  D_145        float64
#  190  target       int64
# dtypes: float64(185), int64(2), object(4)
# memory usage: 7.9+ GB

# %%
if os.path.exists(train_labels_parquet_file):
    os.remove(train_labels_parquet_file)
    print(f"{train_labels_parquet_file} has been removed.")
else:
    print(f"{train_labels_parquet_file} does not exist, so it wasn't removed.")
# Out:
# C:\Users\KonuTech\zoomcamp-capstone-01\data\train_labels.parquet has been removed.

# %%
missing_values = merged_df.isnull().sum()
missing_values
# Out:
# customer_ID          0
# S_2                  0
# P_2              45985
# D_39                 0
# B_1                  0
#                 ...
# D_142          4587043
# D_143           101548
# D_144            40727
# D_145           101548
# target               0
# Length: 191, dtype: int64

# %%
# Step 4: Convert and save the combined DataFrame as a single Parquet file
combined_parquet_file = 'train_data.parquet'

# %%
merged_df.to_parquet(os.path.join(data_dir, combined_parquet_file))

# %%
# Step 5: Remove individual Parquet partitions
for partition_file in parquet_file_paths:
    os.remove(partition_file)

# %%
# Step 6: EDA on the combined Parquet file
parquet_df = pd.read_parquet(os.path.join(data_dir, combined_parquet_file))  # Read the combined Parquet file

# %%
parquet_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Data columns (total 191 columns):
#  #    Column       Dtype
# ---   ------       -----
#  0    customer_ID  object
#  1    S_2          object
#  2    P_2          float64
#  3    D_39         float64
#  4    B_1          float64
#  5    B_2          float64
#  6    R_1          float64
#  7    S_3          float64
#  8    D_41         float64
#  9    B_3          float64
#  10   D_42         float64
#  11   D_43         float64
#  12   D_44         float64
#  13   B_4          float64
#  14   D_45         float64
#  15   B_5          float64
#  16   R_2          float64
#  17   D_46         float64
#  18   D_47         float64
#  19   D_48         float64
#  20   D_49         float64
#  21   B_6          float64
#  22   B_7          float64
#  23   B_8          float64
#  24   D_50         float64
#  25   D_51         float64
#  26   B_9          float64
#  27   R_3          float64
#  28   D_52         float64
#  29   P_3          float64
#  30   B_10         float64
#  31   D_53         float64
#  32   S_5          float64
#  33   B_11         float64
#  34   S_6          float64
#  35   D_54         float64
#  36   R_4          float64
#  37   S_7          float64
#  38   B_12         float64
#  39   S_8          float64
#  40   D_55         float64
#  41   D_56         float64
#  42   B_13         float64
#  43   R_5          float64
#  44   D_58         float64
#  45   S_9          float64
#  46   B_14         float64
#  47   D_59         float64
#  48   D_60         float64
#  49   D_61         float64
#  50   B_15         float64
#  51   S_11         float64
#  52   D_62         float64
#  53   D_63         object
#  54   D_64         object
#  55   D_65         float64
#  56   B_16         float64
#  57   B_17         float64
#  58   B_18         float64
#  59   B_19         float64
#  60   D_66         float64
#  61   B_20         float64
#  62   D_68         float64
#  63   S_12         float64
#  64   R_6          float64
#  65   S_13         float64
#  66   B_21         float64
#  67   D_69         float64
#  68   B_22         float64
#  69   D_70         float64
#  70   D_71         float64
#  71   D_72         float64
#  72   S_15         float64
#  73   B_23         float64
#  74   D_73         float64
#  75   P_4          float64
#  76   D_74         float64
#  77   D_75         float64
#  78   D_76         float64
#  79   B_24         float64
#  80   R_7          float64
#  81   D_77         float64
#  82   B_25         float64
#  83   B_26         float64
#  84   D_78         float64
#  85   D_79         float64
#  86   R_8          float64
#  87   R_9          float64
#  88   S_16         float64
#  89   D_80         float64
#  90   R_10         float64
#  91   R_11         float64
#  92   B_27         float64
#  93   D_81         float64
#  94   D_82         float64
#  95   S_17         float64
#  96   R_12         float64
#  97   B_28         float64
#  98   R_13         float64
#  99   D_83         float64
#  100  R_14         float64
#  101  R_15         float64
#  102  D_84         float64
#  103  R_16         float64
#  104  B_29         float64
#  105  B_30         float64
#  106  S_18         float64
#  107  D_86         float64
#  108  D_87         float64
#  109  R_17         float64
#  110  R_18         float64
#  111  D_88         float64
#  112  B_31         int64
#  113  S_19         float64
#  114  R_19         float64
#  115  B_32         float64
#  116  S_20         float64
#  117  R_20         float64
#  118  R_21         float64
#  119  B_33         float64
#  120  D_89         float64
#  121  R_22         float64
#  122  R_23         float64
#  123  D_91         float64
#  124  D_92         float64
#  125  D_93         float64
#  126  D_94         float64
#  127  R_24         float64
#  128  R_25         float64
#  129  D_96         float64
#  130  S_22         float64
#  131  S_23         float64
#  132  S_24         float64
#  133  S_25         float64
#  134  S_26         float64
#  135  D_102        float64
#  136  D_103        float64
#  137  D_104        float64
#  138  D_105        float64
#  139  D_106        float64
#  140  D_107        float64
#  141  B_36         float64
#  142  B_37         float64
#  143  R_26         float64
#  144  R_27         float64
#  145  B_38         float64
#  146  D_108        float64
#  147  D_109        float64
#  148  D_110        float64
#  149  D_111        float64
#  150  B_39         float64
#  151  D_112        float64
#  152  B_40         float64
#  153  S_27         float64
#  154  D_113        float64
#  155  D_114        float64
#  156  D_115        float64
#  157  D_116        float64
#  158  D_117        float64
#  159  D_118        float64
#  160  D_119        float64
#  161  D_120        float64
#  162  D_121        float64
#  163  D_122        float64
#  164  D_123        float64
#  165  D_124        float64
#  166  D_125        float64
#  167  D_126        float64
#  168  D_127        float64
#  169  D_128        float64
#  170  D_129        float64
#  171  B_41         float64
#  172  B_42         float64
#  173  D_130        float64
#  174  D_131        float64
#  175  D_132        float64
#  176  D_133        float64
#  177  R_28         float64
#  178  D_134        float64
#  179  D_135        float64
#  180  D_136        float64
#  181  D_137        float64
#  182  D_138        float64
#  183  D_139        float64
#  184  D_140        float64
#  185  D_141        float64
#  186  D_142        float64
#  187  D_143        float64
#  188  D_144        float64
#  189  D_145        float64
#  190  target       int64
# dtypes: float64(185), int64(2), object(4)
# memory usage: 7.9+ GB

# %%
parquet_df["customer_ID"].value_counts()
# Out:
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fbac11a8ed792feb62a    13
# a3111280bfa1ed8fafd0b06839eb707f4538497e8087cb62958bb03e1bdde214    13
# a31376930229162f886c091e5a56a528f81c10a523285828ed05a6e9ccf56722    13
# a312c595dfaee96c8a597107d2754a49b1acfd127400d98991762d87837b1b65    13
# a312aff722e7230f9d6a313ff777d6f00166c6bada21a333982426758a2e2a9d    13
#                                                                     ..
# a84839802f1f37a86a7fe34ddba4791d33d878df3937b509841def0a9e252748     1
# 01f4f7b14d83b6a8f88e4355279224615da083b19e3e5f15b98f274ced8cf752     1
# eef07ea56302cebcd57374c6565bb3e5c7af856796d9cbc31ed42aa0fc73b7fc     1
